# %% [markdown]
# # Using the Table below create 4 objects using classes

# %% [markdown]
# | Object              | Attributes                                                                 | Functions                                                        |
# |---------------------|----------------------------------------------------------------------------|------------------------------------------------------------------|
# | **Smartphone**      | - Screen: 6.5 inches<br>- Battery: 4000mAh<br>- System: Android/iOS<br>- Camera: 12MP back, 8MP front<br>- Storage: 128GB | - Call people<br>- Send texts<br>- Use the internet<br>- Take photos and videos<br>- Use apps |
# | **Laptop**          | - Screen: 15.6 inches<br>- Processor: Intel Core i7<br>- RAM: 16GB<br>- Storage: 512GB SSD<br>- System: Windows 10 | - Use programs<br>- Use the internet<br>- Make documents<br>- Video calls<br>- Play games |
# | **Refrigerator**    | - Size: 500 liters<br>- Energy: A++<br>- Doors: 2<br>- Type: Frost-free<br>- Color: Silver | - Keep food cold<br>- Freeze food<br>- Different spaces for food<br>- Give ice and cold water |
# | **Washing Machine** | - Size: 8kg<br>- Type: Front-load<br>- Energy: A+++<br>- Spin: 1400 RPM<br>- Programs: Cotton, Synthetics, Delicates, Quick Wash | - Wash clothes<br>- Rinse and spin clothes<br>- Different washes for different clothes<br>- Change temperature and spin speed |
